# %% [markdown]
# # 6.2 Exploring relationships

# %% [markdown]
# ### This script contains the following:
#
# #### 1. Importing Visualization Libraries and Data
# #### 2. Data Cleaning
# #### 3. Exploring Relationships
#      Correlations
#      Scatterplots
#      Pair Plots
#      Categorical Plots

# %% [markdown]
# ### 1. Importing Visualization Libraries and Data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import os

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# #### Note about matplotlib:
#
# There are certain bugs associated with some versions of matplotlib. Before you start your analysis, you should check what version you have by typing `matplotlib.__version__` in a Jupyter cell and executing it. If it shows version 3.1.1, you'll likely experience some problems with the way the heatmap appears.
#
# To circumvent this, we recommend opening a new Anaconda terminal and executing this command: `conda update --all`. This will update all of your packages and install the newest version of matplotlib, where this bug has been fixed.
#
# Then, restart the kernel for your notebook (so it can pick up any changes to your library versions) and rerun your code, which will re-import the libraries in your notebook. Check the version again, and you should have the latest version installed.

# %%
matplotlib.__version__
# Out:
# '3.5.1'

# %%
# This option ensures the charts you create are displayed in the notebook without the need to "call" them specifically.

# %matplotlib inline

# %%
# Define path

path = r'/Users/arturassada/Desktop/Brazilian E-Commerce'

# %%
# Import data

df = pd.read_csv(os.path.join(path, '02 Data', 'Prepared data', 'data_general.csv'))

# %%
df.head(1)
# Out:
#    Unnamed: 0                          order_id  order_item_id  \
# 0           0  00010242fe8c5a6d1ba2dd792cb16214              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
#
#    shipping_limit_date  price  freight_value  \
# 0  2017-09-19 09:45:35   58.9          13.29
#
#                         customer_id order_status order_purchase_timestamp  \
# 0  3ce436f183e68e07877b285a838db11a    delivered      2017-09-13 08:59:02
#
#      order_approved_at                         review_id  review_score  \
# 0  2017-09-13 09:45:35  97ca439bc427b48bc1cd7177abe71365           5.0
#
#   review_comment_title                customer_unique_id  \
# 0                  NaN  871766c5855e863f6eccc05f988b23cb
#
#    customer_zip_code_prefix          customer_city customer_state  \
# 0                     28013  campos dos goytacazes             RJ
#
#   product_category_name  product_name_lenght  product_description_lenght  \
# 0            cool_stuff                 58.0                       598.0
#
#    product_photos_qty  product_weight_g  product_length_cm  product_height_cm  \
# 0                 4.0             650.0               28.0                9.0
#
#    product_width_cm  seller_zip_code_prefix    seller_city seller_state  \
# 0              14.0                   27277  volta redonda           SP
#
#   product_category_name_english  payment_sequential payment_type  \
# 0                    cool_stuff                 1.0  credit_card
#
#    payment_installments  payment_value
# 0                   2.0          72.19

# %%
df.rename(columns={'customer_zip_code_prefix': 'geolocation_zip_code'}, inplace = True)

# %%
df.describe()
# Out:
#           Unnamed: 0  order_item_id          price  freight_value  \
# count  115723.000000  115723.000000  115723.000000   115723.00000
# mean    59140.988023       1.197048     119.911096       19.98140
# std     34133.638211       0.701221     182.670252       15.71829
# min         0.000000       1.000000       0.850000        0.00000
# 25%     29598.000000       1.000000      39.900000       13.08000
# 50%     59140.000000       1.000000      74.900000       16.28000
# 75%     88679.500000       1.000000     132.900000       21.16000
# max    118309.000000      21.000000    6735.000000      409.68000
#
#         review_score  geolocation_zip_code  product_name_lenght  \
# count  114862.000000         115723.000000        114085.000000
# mean        4.080488          35079.679519            48.802673
# std         1.347659          29855.201461            10.016562
# min         1.000000           1003.000000             5.000000
# 25%         4.000000          11310.000000            42.000000
# 50%         5.000000          24320.000000            52.000000
# 75%         5.000000          58805.500000            57.000000
# max         5.000000          99980.000000            76.000000
#
#        product_description_lenght  product_photos_qty  product_weight_g  \
# count               114085.000000       114085.000000     115703.000000
# mean                   784.854871            2.206408       2105.660303
# std                    650.542538            1.717949       3772.580738
# min                      4.000000            1.000000          0.000000
# 25%                    346.000000            1.000000        300.000000
# 50%                    600.000000            1.000000        700.000000
# 75%                    983.000000            3.000000       1800.000000
# max                   3992.000000           20.000000      40425.000000
#
#        product_length_cm  product_height_cm  product_width_cm  \
# count      115703.000000      115703.000000     115703.000000
# mean           30.239173          16.579881         23.065046
# std            16.126537          13.419841         11.732093
# min             7.000000           2.000000          6.000000
# 25%            18.000000           8.000000         15.000000
# 50%            25.000000          13.000000         20.000000
# 75%            38.000000          20.000000         30.000000
# max           105.000000         105.000000        118.000000
#
#        seller_zip_code_prefix  payment_sequential  payment_installments  \
# count            115723.00000       115720.000000         115720.000000
# mean              24454.55110            1.091272              2.940572
# std               27587.60226            0.686737              2.776111
# min                1001.00000            1.000000              0.000000
# 25%                6429.00000            1.000000              1.000000
# 50%               13660.00000            1.000000              2.000000
# 75%               27930.00000            1.000000              4.000000
# max               99730.00000           26.000000             24.000000
#
#        payment_value
# count  115720.000000
# mean      171.810794
# std       265.642619
# min         0.000000
# 25%        60.850000
# 50%       108.110000
# 75%       188.940000
# max     13664.080000

# %%
df1.head(1)
# Out:
#    geolocation_zip_code  geolocation_lat  geolocation_lng geolocation_city  \
# 0                  1037       -23.545621       -46.639292        sao paulo
#
#   geolocation_state
# 0                SP

# %%
df1.rename(columns={'geolocation_zip_code_prefix': 'geolocation_zip_code'}, inplace = True)

# %%
df1.head(5)
# Out:
#    geolocation_zip_code  geolocation_lat  geolocation_lng geolocation_city  \
# 0                  1037       -23.545621       -46.639292        sao paulo
# 1                  1046       -23.546081       -46.644820        sao paulo
# 2                  1046       -23.546129       -46.642951        sao paulo
# 3                  1041       -23.544392       -46.639499        sao paulo
# 4                  1035       -23.541578       -46.641607        sao paulo
#
#   geolocation_state
# 0                SP
# 1                SP
# 2                SP
# 3                SP
# 4                SP

# %%
merged_df = pd.merge(df, df1, on='geolocation_zip_code', how='left')

# %%
merged_df.head(5)
# Out:
#    Unnamed: 0                          order_id  order_item_id  \
# 0           0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1           0  00010242fe8c5a6d1ba2dd792cb16214              1
# 2           0  00010242fe8c5a6d1ba2dd792cb16214              1
# 3           0  00010242fe8c5a6d1ba2dd792cb16214              1
# 4           0  00010242fe8c5a6d1ba2dd792cb16214              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 2  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 3  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 4  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
#
#    shipping_limit_date  price  freight_value  \
# 0  2017-09-19 09:45:35   58.9          13.29
# 1  2017-09-19 09:45:35   58.9          13.29
# 2  2017-09-19 09:45:35   58.9          13.29
# 3  2017-09-19 09:45:35   58.9          13.29
# 4  2017-09-19 09:45:35   58.9          13.29
#
#                         customer_id order_status order_purchase_timestamp  \
# 0  3ce436f183e68e07877b285a838db11a    delivered      2017-09-13 08:59:02
# 1  3ce436f183e68e07877b285a838db11a    delivered      2017-09-13 08:59:02
# 2  3ce436f183e68e07877b285a838db11a    delivered      2017-09-13 08:59:02
# 3  3ce436f183e68e07877b285a838db11a    delivered      2017-09-13 08:59:02
# 4  3ce436f183e68e07877b285a838db11a    delivered      2017-09-13 08:59:02
#
#      order_approved_at                         review_id  review_score  \
# 0  2017-09-13 09:45:35  97ca439bc427b48bc1cd7177abe71365           5.0
# 1  2017-09-13 09:45:35  97ca439bc427b48bc1cd7177abe71365           5.0
# 2  2017-09-13 09:45:35  97ca439bc427b48bc1cd7177abe71365           5.0
# 3  2017-09-13 09:45:35  97ca439bc427b48bc1cd7177abe71365           5.0
# 4  2017-09-13 09:45:35  97ca439bc427b48bc1cd7177abe71365           5.0
#
#   review_comment_title                customer_unique_id  \
# 0                  NaN  871766c5855e863f6eccc05f988b23cb
# 1                  NaN  871766c5855e863f6eccc05f988b23cb
# 2                  NaN  871766c5855e863f6eccc05f988b23cb
# 3                  NaN  871766c5855e863f6eccc05f988b23cb
# 4                  NaN  871766c5855e863f6eccc05f988b23cb
#
#    geolocation_zip_code          customer_city customer_state  \
# 0                 28013  campos dos goytacazes             RJ
# 1                 28013  campos dos goytacazes             RJ
# 2                 28013  campos dos goytacazes             RJ
# 3                 28013  campos dos goytacazes             RJ
# 4                 28013  campos dos goytacazes             RJ
#
#   product_category_name  product_name_lenght  product_description_lenght  \
# 0            cool_stuff                 58.0                       598.0
# 1            cool_stuff                 58.0                       598.0
# 2            cool_stuff                 58.0                       598.0
# 3            cool_stuff                 58.0                       598.0
# 4            cool_stuff                 58.0                       598.0
#
#    product_photos_qty  product_weight_g  product_length_cm  product_height_cm  \
# 0                 4.0             650.0               28.0                9.0
# 1                 4.0             650.0               28.0                9.0
# 2                 4.0             650.0               28.0                9.0
# 3                 4.0             650.0               28.0                9.0
# 4                 4.0             650.0               28.0                9.0
#
#    product_width_cm  seller_zip_code_prefix    seller_city seller_state  \
# 0              14.0                   27277  volta redonda           SP
# 1              14.0                   27277  volta redonda           SP
# 2              14.0                   27277  volta redonda           SP
# 3              14.0                   27277  volta redonda           SP
# 4              14.0                   27277  volta redonda           SP
#
#   product_category_name_english  payment_sequential payment_type  \
# 0                    cool_stuff                 1.0  credit_card
# 1                    cool_stuff                 1.0  credit_card
# 2                    cool_stuff                 1.0  credit_card
# 3                    cool_stuff                 1.0  credit_card
# 4                    cool_stuff                 1.0  credit_card
#
#    payment_installments  payment_value  geolocation_lat  geolocation_lng  \
# 0                   2.0          72.19       -21.758076       -41.312633
# 1                   2.0          72.19       -21.758843       -41.306754
# 2                   2.0          72.19       -21.767046       -41.311328
# 3                   2.0          72.19       -21.771661       -41.312119
# 4                   2.0          72.19       -21.763006       -41.306182
#
#         geolocation_city geolocation_state
# 0  campos dos goytacazes                RJ
# 1  campos dos goytacazes                RJ
# 2  campos dos goytacazes                RJ
# 3  campos dos goytacazes                RJ
# 4  campos dos goytacazes                RJ

# %%
merged_df.drop(['shipping_limit_date', 'seller_id', 'order_approved_at','product_description_lenght', 'product_weight_g', 'product_length_cm', 'product_height_cm', 'product_width_cm', 'seller_zip_code_prefix', 'seller_city', 'seller_state'], axis=1)
# Out:
#           Unnamed: 0                          order_id  order_item_id  \
# 0                  0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1                  0  00010242fe8c5a6d1ba2dd792cb16214              1
# 2                  0  00010242fe8c5a6d1ba2dd792cb16214              1
# 3                  0  00010242fe8c5a6d1ba2dd792cb16214              1
# 4                  0  00010242fe8c5a6d1ba2dd792cb16214              1
# ...              ...                               ...            ...
# 17692290      118309  fffe41c64501cc87c801fd61db3f6244              1
# 17692291      118309  fffe41c64501cc87c801fd61db3f6244              1
# 17692292      118309  fffe41c64501cc87c801fd61db3f6244              1
# 17692293      118309  fffe41c64501cc87c801fd61db3f6244              1
# 17692294      118309  fffe41c64501cc87c801fd61db3f6244              1
#
#                                 product_id  price  freight_value  \
# 0         4244733e06e7ecb4970a6e2683c13e61   58.9          13.29
# 1         4244733e06e7ecb4970a6e2683c13e61   58.9          13.29
# 2         4244733e06e7ecb4970a6e2683c13e61   58.9          13.29
# 3         4244733e06e7ecb4970a6e2683c13e61   58.9          13.29
# 4         4244733e06e7ecb4970a6e2683c13e61   58.9          13.29
# ...                                    ...    ...            ...
# 17692290  350688d9dc1e75ff97be326363655e01   43.0          12.79
# 17692291  350688d9dc1e75ff97be326363655e01   43.0          12.79
# 17692292  350688d9dc1e75ff97be326363655e01   43.0          12.79
# 17692293  350688d9dc1e75ff97be326363655e01   43.0          12.79
# 17692294  350688d9dc1e75ff97be326363655e01   43.0          12.79
#
#                                customer_id order_status  \
# 0         3ce436f183e68e07877b285a838db11a    delivered
# 1         3ce436f183e68e07877b285a838db11a    delivered
# 2         3ce436f183e68e07877b285a838db11a    delivered
# 3         3ce436f183e68e07877b285a838db11a    delivered
# 4         3ce436f183e68e07877b285a838db11a    delivered
# ...                                    ...          ...
# 17692290  96d649da0cc4ff33bb408b199d4c7dcf    delivered
# 17692291  96d649da0cc4ff33bb408b199d4c7dcf    delivered
# 17692292  96d649da0cc4ff33bb408b199d4c7dcf    delivered
# 17692293  96d649da0cc4ff33bb408b199d4c7dcf    delivered
# 17692294  96d649da0cc4ff33bb408b199d4c7dcf    delivered
#
#          order_purchase_timestamp                         review_id  \
# 0             2017-09-13 08:59:02  97ca439bc427b48bc1cd7177abe71365
# 1             2017-09-13 08:59:02  97ca439bc427b48bc1cd7177abe71365
# 2             2017-09-13 08:59:02  97ca439bc427b48bc1cd7177abe71365
# 3             2017-09-13 08:59:02  97ca439bc427b48bc1cd7177abe71365
# 4             2017-09-13 08:59:02  97ca439bc427b48bc1cd7177abe71365
# ...                           ...                               ...
# 17692290      2018-06-09 17:00:18  b2700869a37f1aafc9dda829dc2f9027
# 17692291      2018-06-09 17:00:18  b2700869a37f1aafc9dda829dc2f9027
# 17692292      2018-06-09 17:00:18  b2700869a37f1aafc9dda829dc2f9027
# 17692293      2018-06-09 17:00:18  b2700869a37f1aafc9dda829dc2f9027
# 17692294      2018-06-09 17:00:18  b2700869a37f1aafc9dda829dc2f9027
#
#           review_score review_comment_title                customer_unique_id  \
# 0                  5.0                  NaN  871766c5855e863f6eccc05f988b23cb
# 1                  5.0                  NaN  871766c5855e863f6eccc05f988b23cb
# 2                  5.0                  NaN  871766c5855e863f6eccc05f988b23cb
# 3                  5.0                  NaN  871766c5855e863f6eccc05f988b23cb
# 4                  5.0                  NaN  871766c5855e863f6eccc05f988b23cb
# ...                ...                  ...                               ...
# 17692290           5.0                  NaN  cd76a00d8e3ca5e6ab9ed9ecb6667ac4
# 17692291           5.0                  NaN  cd76a00d8e3ca5e6ab9ed9ecb6667ac4
# 17692292           5.0                  NaN  cd76a00d8e3ca5e6ab9ed9ecb6667ac4
# 17692293           5.0                  NaN  cd76a00d8e3ca5e6ab9ed9ecb6667ac4
# 17692294           5.0                  NaN  cd76a00d8e3ca5e6ab9ed9ecb6667ac4
#
#           geolocation_zip_code          customer_city customer_state  \
# 0                        28013  campos dos goytacazes             RJ
# 1                        28013  campos dos goytacazes             RJ
# 2                        28013  campos dos goytacazes             RJ
# 3                        28013  campos dos goytacazes             RJ
# 4                        28013  campos dos goytacazes             RJ
# ...                        ...                    ...            ...
# 17692290                 18605               botucatu             SP
# 17692291                 18605               botucatu             SP
# 17692292                 18605               botucatu             SP
# 17692293                 18605               botucatu             SP
# 17692294                 18605               botucatu             SP
#
#          product_category_name  product_name_lenght  product_photos_qty  \
# 0                   cool_stuff                 58.0                 4.0
# 1                   cool_stuff                 58.0                 4.0
# 2                   cool_stuff                 58.0                 4.0
# 3                   cool_stuff                 58.0                 4.0
# 4                   cool_stuff                 58.0                 4.0
# ...                        ...                  ...                 ...
# 17692290       cama_mesa_banho                 47.0                 1.0
# 17692291       cama_mesa_banho                 47.0                 1.0
# 17692292       cama_mesa_banho                 47.0                 1.0
# 17692293       cama_mesa_banho                 47.0                 1.0
# 17692294       cama_mesa_banho                 47.0                 1.0
#
#          product_category_name_english  payment_sequential payment_type  \
# 0                           cool_stuff                 1.0  credit_card
# 1                           cool_stuff                 1.0  credit_card
# 2                           cool_stuff                 1.0  credit_card
# 3                           cool_stuff                 1.0  credit_card
# 4                           cool_stuff                 1.0  credit_card
# ...                                ...                 ...          ...
# 17692290                bed_bath_table                 1.0  credit_card
# 17692291                bed_bath_table                 1.0  credit_card
# 17692292                bed_bath_table                 1.0  credit_card
# 17692293                bed_bath_table                 1.0  credit_card
# 17692294                bed_bath_table                 1.0  credit_card
#
#           payment_installments  payment_value  geolocation_lat  \
# 0                          2.0          72.19       -21.758076
# 1                          2.0          72.19       -21.758843
# 2                          2.0          72.19       -21.767046
# 3                          2.0          72.19       -21.771661
# 4                          2.0          72.19       -21.763006
# ...                        ...            ...              ...
# 17692290                   1.0          55.79       -22.934277
# 17692291                   1.0          55.79       -22.910668
# 17692292                   1.0          55.79       -22.918155
# 17692293                   1.0          55.79       -22.906315
# 17692294                   1.0          55.79       -22.927341
#
#           geolocation_lng       geolocation_city geolocation_state
# 0              -41.312633  campos dos goytacazes                RJ
# 1              -41.306754  campos dos goytacazes                RJ
# 2              -41.311328  campos dos goytacazes                RJ
# 3              -41.312119  campos dos goytacazes                RJ
# 4              -41.306182  campos dos goytacazes                RJ
# ...                   ...                    ...               ...
# 17692290       -48.454793               botucatu                SP
# 17692291       -48.442521               botucatu                SP
# 17692292       -48.439639               botucatu                SP
# 17692293       -48.444961               botucatu                SP
# 17692294       -48.451554               botucatu                SP
#
# [17692295 rows x 28 columns]

# %%
merged_df.head(5)
# Out:
#    Unnamed: 0                          order_id  order_item_id  \
# 0           0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1           0  00010242fe8c5a6d1ba2dd792cb16214              1
# 2           0  00010242fe8c5a6d1ba2dd792cb16214              1
# 3           0  00010242fe8c5a6d1ba2dd792cb16214              1
# 4           0  00010242fe8c5a6d1ba2dd792cb16214              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 2  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 3  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 4  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
#
#    shipping_limit_date  price  freight_value  \
# 0  2017-09-19 09:45:35   58.9          13.29
# 1  2017-09-19 09:45:35   58.9          13.29
# 2  2017-09-19 09:45:35   58.9          13.29
# 3  2017-09-19 09:45:35   58.9          13.29
# 4  2017-09-19 09:45:35   58.9          13.29
#
#                         customer_id order_status order_purchase_timestamp  \
# 0  3ce436f183e68e07877b285a838db11a    delivered      2017-09-13 08:59:02
# 1  3ce436f183e68e07877b285a838db11a    delivered      2017-09-13 08:59:02
# 2  3ce436f183e68e07877b285a838db11a    delivered      2017-09-13 08:59:02
# 3  3ce436f183e68e07877b285a838db11a    delivered      2017-09-13 08:59:02
# 4  3ce436f183e68e07877b285a838db11a    delivered      2017-09-13 08:59:02
#
#      order_approved_at                         review_id  review_score  \
# 0  2017-09-13 09:45:35  97ca439bc427b48bc1cd7177abe71365           5.0
# 1  2017-09-13 09:45:35  97ca439bc427b48bc1cd7177abe71365           5.0
# 2  2017-09-13 09:45:35  97ca439bc427b48bc1cd7177abe71365           5.0
# 3  2017-09-13 09:45:35  97ca439bc427b48bc1cd7177abe71365           5.0
# 4  2017-09-13 09:45:35  97ca439bc427b48bc1cd7177abe71365           5.0
#
#   review_comment_title                customer_unique_id  \
# 0                  NaN  871766c5855e863f6eccc05f988b23cb
# 1                  NaN  871766c5855e863f6eccc05f988b23cb
# 2                  NaN  871766c5855e863f6eccc05f988b23cb
# 3                  NaN  871766c5855e863f6eccc05f988b23cb
# 4                  NaN  871766c5855e863f6eccc05f988b23cb
#
#    geolocation_zip_code          customer_city customer_state  \
# 0                 28013  campos dos goytacazes             RJ
# 1                 28013  campos dos goytacazes             RJ
# 2                 28013  campos dos goytacazes             RJ
# 3                 28013  campos dos goytacazes             RJ
# 4                 28013  campos dos goytacazes             RJ
#
#   product_category_name  product_name_lenght  product_description_lenght  \
# 0            cool_stuff                 58.0                       598.0
# 1            cool_stuff                 58.0                       598.0
# 2            cool_stuff                 58.0                       598.0
# 3            cool_stuff                 58.0                       598.0
# 4            cool_stuff                 58.0                       598.0
#
#    product_photos_qty  product_weight_g  product_length_cm  product_height_cm  \
# 0                 4.0             650.0               28.0                9.0
# 1                 4.0             650.0               28.0                9.0
# 2                 4.0             650.0               28.0                9.0
# 3                 4.0             650.0               28.0                9.0
# 4                 4.0             650.0               28.0                9.0
#
#    product_width_cm  seller_zip_code_prefix    seller_city seller_state  \
# 0              14.0                   27277  volta redonda           SP
# 1              14.0                   27277  volta redonda           SP
# 2              14.0                   27277  volta redonda           SP
# 3              14.0                   27277  volta redonda           SP
# 4              14.0                   27277  volta redonda           SP
#
#   product_category_name_english  payment_sequential payment_type  \
# 0                    cool_stuff                 1.0  credit_card
# 1                    cool_stuff                 1.0  credit_card
# 2                    cool_stuff                 1.0  credit_card
# 3                    cool_stuff                 1.0  credit_card
# 4                    cool_stuff                 1.0  credit_card
#
#    payment_installments  payment_value  geolocation_lat  geolocation_lng  \
# 0                   2.0          72.19       -21.758076       -41.312633
# 1                   2.0          72.19       -21.758843       -41.306754
# 2                   2.0          72.19       -21.767046       -41.311328
# 3                   2.0          72.19       -21.771661       -41.312119
# 4                   2.0          72.19       -21.763006       -41.306182
#
#         geolocation_city geolocation_state
# 0  campos dos goytacazes                RJ
# 1  campos dos goytacazes                RJ
# 2  campos dos goytacazes                RJ
# 3  campos dos goytacazes                RJ
# 4  campos dos goytacazes                RJ

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17692295 entries, 0 to 17692294
# Data columns (total 39 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   Unnamed: 0                     int64
#  1   order_id                       object
#  2   order_item_id                  int64
#  3   product_id                     object
#  4   seller_id                      object
#  5   shipping_limit_date            object
#  6   price                          float64
#  7   freight_value                  float64
#  8   customer_id                    object
#  9   order_status                   object
#  10  order_purchase_timestamp       object
#  11  order_approved_at              object
#  12  review_id                      object
#  13  review_score                   float64
#  14  review_comment_title           object
#  15  customer_unique_id             object
#  16  geolocation_zip_code           int64
#  17  customer_city                  object
#  18  customer_state                 object
#  19  product_category_name          object
#  20  product_name_lenght            float64
#  21  product_description_lenght     float64
#  22  product_photos_qty             float64
#  23  product_weight_g               float64
#  24  product_length_cm              float64
#  25  product_height_cm              float64
#  26  product_width_cm               float64
#  27  seller_zip_code_prefix         int64
#  28  seller_city                    object
#  29  seller_state                   object
#  30  product_category_name_english  object
#  31  payment_sequential             float64
#  32  payment_type                   object
#  33  payment_installments           float64
#  34  payment_value                  float64
#  35  geolocation_lat                float64
#  36  geolocation_lng                float64
#  37  geolocation_city               object
#  38  geolocation_state              object
# dtypes: float64(15), int64(4), object(20)
# memory usage: 5.3+ GB

# %%
merged_df.isnull().sum()
# Out:
# Unnamed: 0                              0
# order_id                                0
# order_item_id                           0
# product_id                              0
# seller_id                               0
# shipping_limit_date                     0
# price                                   0
# freight_value                           0
# customer_id                             0
# order_status                            0
# order_purchase_timestamp                0
# order_approved_at                    2994
# review_id                          123389
# review_score                       123389
# review_comment_title             15715228
# customer_unique_id                      0
# geolocation_zip_code                    0
# customer_city                           0
# customer_state                          0
# product_category_name              251499
# product_name_lenght                251499
# product_description_lenght         251499
# product_photos_qty                 251499
# product_weight_g                     3678
# product_length_cm                    3678
# product_height_cm                    3678
# product_width_cm                     3678
# seller_zip_code_prefix                  0
# seller_city                             0
# seller_state                            0
# product_category_name_english      254907
# payment_sequential                   1035
# payment_type                         1035
# payment_installments                 1035
# payment_value                        1035
# geolocation_lat                       303
# geolocation_lng                       303
# geolocation_city                      303
# geolocation_state                     303
# dtype: int64

# %%
newdf = merged_df.dropna()

# %%
newdf.isnull().sum()
# Out:
# Unnamed: 0                       0
# order_id                         0
# order_item_id                    0
# product_id                       0
# seller_id                        0
# shipping_limit_date              0
# price                            0
# freight_value                    0
# customer_id                      0
# order_status                     0
# order_purchase_timestamp         0
# order_approved_at                0
# review_id                        0
# review_score                     0
# review_comment_title             0
# customer_unique_id               0
# geolocation_zip_code             0
# customer_city                    0
# customer_state                   0
# product_category_name            0
# product_name_lenght              0
# product_description_lenght       0
# product_photos_qty               0
# product_weight_g                 0
# product_length_cm                0
# product_height_cm                0
# product_width_cm                 0
# seller_zip_code_prefix           0
# seller_city                      0
# seller_state                     0
# product_category_name_english    0
# payment_sequential               0
# payment_type                     0
# payment_installments             0
# payment_value                    0
# geolocation_lat                  0
# geolocation_lng                  0
# geolocation_city                 0
# geolocation_state                0
# dtype: int64

# %%
newdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1964843 entries, 2374 to 17686615
# Data columns (total 39 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   Unnamed: 0                     int64
#  1   order_id                       object
#  2   order_item_id                  int64
#  3   product_id                     object
#  4   seller_id                      object
#  5   shipping_limit_date            object
#  6   price                          float64
#  7   freight_value                  float64
#  8   customer_id                    object
#  9   order_status                   object
#  10  order_purchase_timestamp       object
#  11  order_approved_at              object
#  12  review_id                      object
#  13  review_score                   float64
#  14  review_comment_title           object
#  15  customer_unique_id             object
#  16  geolocation_zip_code           int64
#  17  customer_city                  object
#  18  customer_state                 object
#  19  product_category_name          object
#  20  product_name_lenght            float64
#  21  product_description_lenght     float64
#  22  product_photos_qty             float64
#  23  product_weight_g               float64
#  24  product_length_cm              float64
#  25  product_height_cm              float64
#  26  product_width_cm               float64
#  27  seller_zip_code_prefix         int64
#  28  seller_city                    object
#  29  seller_state                   object
#  30  product_category_name_english  object
#  31  payment_sequential             float64
#  32  payment_type                   object
#  33  payment_installments           float64
#  34  payment_value                  float64
#  35  geolocation_lat                float64
#  36  geolocation_lng                float64
#  37  geolocation_city               object
#  38  geolocation_state              object
# dtypes: float64(15), int64(4), object(20)
# memory usage: 599.6+ MB

# %%
df.to_csv(os.path.join(path, '02 Data', 'Prepared data', 'data_general_clean.csv'))
